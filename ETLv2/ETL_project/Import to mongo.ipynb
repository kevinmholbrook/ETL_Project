# %%
#Import Dependencies
import re
import numpy as np
import pandas as pd
from sqlalchemy import create_engine

# %% [raw]
# ##################################################################################################################
# ### SECTION 1
# # READ in the california.csv file
# ##################################################################################################################

# %%
#California_Cannabis_Distributer_Data
california_data = "../ETL_project/california_data.csv"
california_data_df = pd.read_csv(california_data)
california_data_df.head()
# Out:
#     License Number                    License Type  \
# 0  C11-0000034-LIC  Cannabis - Distributor License
# 1  C11-0000035-LIC  Cannabis - Distributor License
# 2  C11-0000036-LIC  Cannabis - Distributor License
# 3  C11-0000037-LIC  Cannabis - Distributor License
# 4  C10-0000028-LIC     Cannabis - Retailer License
#
#                    Business Owner  \
# 0                Bernard Steimann
# 1                  Alicia Schultz
# 2                    Connie Bauer
# 3              Marcella Castaneda
# 4  Chelsea Sutula: Chelsea Sutula
#
#                         Business Contact Information  \
# 0  PDC, LLC : Email- license@pmcoc.com : Phone- 7...
# 1  WE CARE CAT CITY INC.  : GUIDE : Email- George...
# 2  GREENFIELD HERBS  : Greenfield Herbs : Email- ...
# 3  BEAVER FREIGHT, INC. : Email- mcastaneda85@gma...
# 4  SESPE CREEK COLLECTIVE, INC. : Email- info@ses...
#
#           Business Structure                                 Premise Address  \
# 0  Limited Liability Company  CATHEDRAL CITY, CA 922347624 County: RIVERSIDE
# 1                Corporation      Cathedral City, CA 92234 County: RIVERSIDE
# 2                Corporation            KING CITY, CA 93930 County: MONTEREY
# 3                Corporation       ADELANTO, CA 92301 County: SAN BERNARDINO
# 4                Corporation   408 BRYANT CIR OJAI, CA 93023 County: VENTURA
#
#    Status  Issue Date Expiration Date                 Activities  \
# 0  Active  05/02/2019      05/01/2020  N/A for this license type
# 1  Active  05/02/2019      05/01/2020  N/A for this license type
# 2  Active  05/02/2019      05/01/2020  N/A for this license type
# 3  Active  05/02/2019      05/01/2020  N/A for this license type
# 4  Active  05/01/2019      04/30/2020  N/A for this license type
#
#   Adult-Use/Medicinal
# 0                BOTH
# 1                BOTH
# 2                BOTH
# 3           Medicinal
# 4                BOTH

# %%
#Individual column names in california_data_df
list(california_data_df)
# Out:
# ['License Number',
#  'License Type',
#  'Business Owner',
#  'Business Contact Information',
#  'Business Structure',
#  'Premise Address',
#  'Status',
#  'Issue Date',
#  'Expiration Date',
#  'Activities',
#  'Adult-Use/Medicinal']

# %% [raw]
# ##################################################################################################################
# ### SECTION 2
# # Clean the data in the california.csv file
# ##################################################################################################################

# %% [raw]
# ##################################################################################################################
# ## SECTION 2.1
# #Clean the "Business Contact Information" column
# ##Objective: Clean the data in california_data_df["Business Contact Information"]
# ##################################################################################################################

# %%
#Note that there are multiple delimiters: a colon (":"), a dash ("-"), a comma (","), and a blank space (" ")
california_data_df["Business Contact Information"].head()
# Out:
# 0    PDC, LLC : Email- license@pmcoc.com : Phone- 7...
# 1    WE CARE CAT CITY INC.  : GUIDE : Email- George...
# 2    GREENFIELD HERBS  : Greenfield Herbs : Email- ...
# 3    BEAVER FREIGHT, INC. : Email- mcastaneda85@gma...
# 4    SESPE CREEK COLLECTIVE, INC. : Email- info@ses...
# Name: Business Contact Information, dtype: object

# %%
##Extract and separate "Business Name" from the california_data_df["Business Contact Information"] column

# dropping null value columns to avoid errors 
california_data_df.dropna(inplace = True) 
  
# new dataframe with split value columns 
new = california_data_df["Business Contact Information"].str.split(":", n = 1, expand = True) 
  
# making separate "Business Name" column from new data frame 
california_data_df["Business Name"]= new[0] 
  
# making separate "Contact Information" column from new data frame 
california_data_df["Contact Information"]= new[1] 

# Dropping old "Business Contact Information" column
california_data_df.drop(columns =["Business Contact Information"], inplace = True) 

#california_data_df display with the new columns
## Note: california_data_df["Business Name"] and california_data_df["Contact Information"] BOTH need cleaning 
california_data_df.head()
# Out:
#     License Number                    License Type  \
# 0  C11-0000034-LIC  Cannabis - Distributor License
# 1  C11-0000035-LIC  Cannabis - Distributor License
# 2  C11-0000036-LIC  Cannabis - Distributor License
# 3  C11-0000037-LIC  Cannabis - Distributor License
# 4  C10-0000028-LIC     Cannabis - Retailer License
#
#                    Business Owner         Business Structure  \
# 0                Bernard Steimann  Limited Liability Company
# 1                  Alicia Schultz                Corporation
# 2                    Connie Bauer                Corporation
# 3              Marcella Castaneda                Corporation
# 4  Chelsea Sutula: Chelsea Sutula                Corporation
#
#                                   Premise Address  Status  Issue Date  \
# 0  CATHEDRAL CITY, CA 922347624 County: RIVERSIDE  Active  05/02/2019
# 1      Cathedral City, CA 92234 County: RIVERSIDE  Active  05/02/2019
# 2            KING CITY, CA 93930 County: MONTEREY  Active  05/02/2019
# 3       ADELANTO, CA 92301 County: SAN BERNARDINO  Active  05/02/2019
# 4   408 BRYANT CIR OJAI, CA 93023 County: VENTURA  Active  05/01/2019
#
#   Expiration Date                 Activities Adult-Use/Medicinal  \
# 0      05/01/2020  N/A for this license type                BOTH
# 1      05/01/2020  N/A for this license type                BOTH
# 2      05/01/2020  N/A for this license type                BOTH
# 3      05/01/2020  N/A for this license type           Medicinal
# 4      04/30/2020  N/A for this license type                BOTH
#
#                    Business Name  \
# 0                      PDC, LLC
# 1        WE CARE CAT CITY INC.
# 2             GREENFIELD HERBS
# 3          BEAVER FREIGHT, INC.
# 4  SESPE CREEK COLLECTIVE, INC.
#
#                                  Contact Information
# 0   Email- license@pmcoc.com : Phone- 7144857379 ...
# 1   GUIDE : Email- Georgedggroup@gmail.com : Phon...
# 2   Greenfield Herbs : Email- carol@greenfieldher...
# 3   Email- mcastaneda85@gmail.com : Phone- 909963...
# 4   Email- info@sespe.org : Phone- 8557229333 : W...

# %%
##Extract the occasional extraneous "Business Name" info from the california_data_df["Contact Information"] column 

# dropping null value columns to avoid errors 
california_data_df.dropna(inplace = True) 
  
# new data frame with split value columns 
new = california_data_df["Contact Information"].str.split("Email-", n = 1, expand = True) 
  
# making separate "Extra Business Name Information" column from new data frame that contains the occasional extraneous "Business Name" info.
california_data_df["Extra Business Name Information"]= new[0] 
  
# making separate "Contact Information2"column from new data frame 
california_data_df["Contact Information2"]= new[1] 

# Dropping old "Contact Information" column
california_data_df.drop(columns =["Contact Information"], inplace = True) 

#california_data_df display with the new columns
## Note: we must now combine california_data_df["Business Name"] with california_data_df["Extra Business Name Information"]
## Note: california_data_df["Contact Information2"] still needs cleaning
california_data_df.head()
# Out:
#     License Number                    License Type  \
# 0  C11-0000034-LIC  Cannabis - Distributor License
# 1  C11-0000035-LIC  Cannabis - Distributor License
# 2  C11-0000036-LIC  Cannabis - Distributor License
# 3  C11-0000037-LIC  Cannabis - Distributor License
# 4  C10-0000028-LIC     Cannabis - Retailer License
#
#                    Business Owner         Business Structure  \
# 0                Bernard Steimann  Limited Liability Company
# 1                  Alicia Schultz                Corporation
# 2                    Connie Bauer                Corporation
# 3              Marcella Castaneda                Corporation
# 4  Chelsea Sutula: Chelsea Sutula                Corporation
#
#                                   Premise Address  Status  Issue Date  \
# 0  CATHEDRAL CITY, CA 922347624 County: RIVERSIDE  Active  05/02/2019
# 1      Cathedral City, CA 92234 County: RIVERSIDE  Active  05/02/2019
# 2            KING CITY, CA 93930 County: MONTEREY  Active  05/02/2019
# 3       ADELANTO, CA 92301 County: SAN BERNARDINO  Active  05/02/2019
# 4   408 BRYANT CIR OJAI, CA 93023 County: VENTURA  Active  05/01/2019
#
#   Expiration Date                 Activities Adult-Use/Medicinal  \
# 0      05/01/2020  N/A for this license type                BOTH
# 1      05/01/2020  N/A for this license type                BOTH
# 2      05/01/2020  N/A for this license type                BOTH
# 3      05/01/2020  N/A for this license type           Medicinal
# 4      04/30/2020  N/A for this license type                BOTH
#
#                    Business Name Extra Business Name Information  \
# 0                      PDC, LLC
# 1        WE CARE CAT CITY INC.                          GUIDE :
# 2             GREENFIELD HERBS               Greenfield Herbs :
# 3          BEAVER FREIGHT, INC.
# 4  SESPE CREEK COLLECTIVE, INC.
#
#                                 Contact Information2
# 0   license@pmcoc.com : Phone- 7144857379 : Websi...
# 1        Georgedggroup@gmail.com : Phone- 7606737220
# 2      carol@greenfieldherbs.com : Phone- 8318095469
# 3         mcastaneda85@gmail.com : Phone- 9099638849
# 4   info@sespe.org : Phone- 8557229333 : Website-...

# %%
#Combine california_data_df["Business Name"] with california_data_df["Extra Business Name Information"] and clean
california_data_df['Company Name'] = california_data_df['Business Name'].str.cat(california_data_df['Extra Business Name Information'],sep=" ")
california_data_df["Company Name"] = california_data_df["Company Name"].str.replace(':,?' , '')

# Dropping california_data_df["Business Name]" and california_data_df["Extra Business Name Information"] columns
california_data_df.drop(columns =["Business Name"], inplace = True)
california_data_df.drop(columns =["Extra Business Name Information"], inplace = True)

#california_data_df display with the new column (california_data_df["Company Name"])
##Note: california_data_df["Contact Information2"] still needs cleaning
california_data_df.head()
# Out:
#     License Number                    License Type  \
# 0  C11-0000034-LIC  Cannabis - Distributor License
# 1  C11-0000035-LIC  Cannabis - Distributor License
# 2  C11-0000036-LIC  Cannabis - Distributor License
# 3  C11-0000037-LIC  Cannabis - Distributor License
# 4  C10-0000028-LIC     Cannabis - Retailer License
#
#                    Business Owner         Business Structure  \
# 0                Bernard Steimann  Limited Liability Company
# 1                  Alicia Schultz                Corporation
# 2                    Connie Bauer                Corporation
# 3              Marcella Castaneda                Corporation
# 4  Chelsea Sutula: Chelsea Sutula                Corporation
#
#                                   Premise Address  Status  Issue Date  \
# 0  CATHEDRAL CITY, CA 922347624 County: RIVERSIDE  Active  05/02/2019
# 1      Cathedral City, CA 92234 County: RIVERSIDE  Active  05/02/2019
# 2            KING CITY, CA 93930 County: MONTEREY  Active  05/02/2019
# 3       ADELANTO, CA 92301 County: SAN BERNARDINO  Active  05/02/2019
# 4   408 BRYANT CIR OJAI, CA 93023 County: VENTURA  Active  05/01/2019
#
#   Expiration Date                 Activities Adult-Use/Medicinal  \
# 0      05/01/2020  N/A for this license type                BOTH
# 1      05/01/2020  N/A for this license type                BOTH
# 2      05/01/2020  N/A for this license type                BOTH
# 3      05/01/2020  N/A for this license type           Medicinal
# 4      04/30/2020  N/A for this license type                BOTH
#
#                                 Contact Information2  \
# 0   license@pmcoc.com : Phone- 7144857379 : Websi...
# 1        Georgedggroup@gmail.com : Phone- 7606737220
# 2      carol@greenfieldherbs.com : Phone- 8318095469
# 3         mcastaneda85@gmail.com : Phone- 9099638849
# 4   info@sespe.org : Phone- 8557229333 : Website-...
#
#                              Company Name
# 0                             PDC, LLC
# 1        WE CARE CAT CITY INC.    GUIDE
# 2  GREENFIELD HERBS    Greenfield Herbs
# 3                 BEAVER FREIGHT, INC.
# 4         SESPE CREEK COLLECTIVE, INC.

# %%
##Extract and separate "Email" from the california_data_df["Contact Information2"] column

# dropping null value columns to avoid errors 
california_data_df.dropna(inplace = True) 
  
# new data frame with split value columns 
new = california_data_df["Contact Information2"].str.split(":", n = 1, expand = True) 
  
# making separate "Business Name" column from new data frame 
california_data_df["Email"]= new[0] 
  
# making separate "Contact Information" column from new data frame 
california_data_df["Contact Information3"]= new[1] 

# Dropping california_data_df["Contact Information2"] column
california_data_df.drop(columns =["Contact Information2"], inplace = True) 

#california_data_df display with the new columns
##Note: california_data_df["Contact Information3"] still needs cleaning
california_data_df.head()
# Out:
#     License Number                    License Type  \
# 0  C11-0000034-LIC  Cannabis - Distributor License
# 1  C11-0000035-LIC  Cannabis - Distributor License
# 2  C11-0000036-LIC  Cannabis - Distributor License
# 3  C11-0000037-LIC  Cannabis - Distributor License
# 4  C10-0000028-LIC     Cannabis - Retailer License
#
#                    Business Owner         Business Structure  \
# 0                Bernard Steimann  Limited Liability Company
# 1                  Alicia Schultz                Corporation
# 2                    Connie Bauer                Corporation
# 3              Marcella Castaneda                Corporation
# 4  Chelsea Sutula: Chelsea Sutula                Corporation
#
#                                   Premise Address  Status  Issue Date  \
# 0  CATHEDRAL CITY, CA 922347624 County: RIVERSIDE  Active  05/02/2019
# 1      Cathedral City, CA 92234 County: RIVERSIDE  Active  05/02/2019
# 2            KING CITY, CA 93930 County: MONTEREY  Active  05/02/2019
# 3       ADELANTO, CA 92301 County: SAN BERNARDINO  Active  05/02/2019
# 4   408 BRYANT CIR OJAI, CA 93023 County: VENTURA  Active  05/01/2019
#
#   Expiration Date                 Activities Adult-Use/Medicinal  \
# 0      05/01/2020  N/A for this license type                BOTH
# 1      05/01/2020  N/A for this license type                BOTH
# 2      05/01/2020  N/A for this license type                BOTH
# 3      05/01/2020  N/A for this license type           Medicinal
# 4      04/30/2020  N/A for this license type                BOTH
#
#                              Company Name                        Email  \
# 0                             PDC, LLC              license@pmcoc.com
# 1        WE CARE CAT CITY INC.    GUIDE       Georgedggroup@gmail.com
# 2  GREENFIELD HERBS    Greenfield Herbs     carol@greenfieldherbs.com
# 3                 BEAVER FREIGHT, INC.         mcastaneda85@gmail.com
# 4         SESPE CREEK COLLECTIVE, INC.                 info@sespe.org
#
#                                Contact Information3
# 0   Phone- 7144857379 : Website- www.herodistro.com
# 1                                 Phone- 7606737220
# 2                                 Phone- 8318095469
# 3                                 Phone- 9099638849
# 4        Phone- 8557229333 : Website- www.sespe.org

# %%
##Extract and separate "Phone Number" from the california_data_df["Contact Information3"] column.

# dropping null value columns to avoid errors 
california_data_df.dropna(inplace = True) 
  
# new data frame with split value columns 
new = california_data_df["Contact Information3"].str.split(":", n = 1, expand = True) 
  
# making separate "Business Name" column from new data frame 
california_data_df["Phone Number"]= new[0] 
  
# making separate "Contact Information" column from new data frame 
california_data_df["Contact Information4"]= new[1] 

# Dropping california_data_df["Contact Information"] column
california_data_df.drop(columns =["Contact Information3"], inplace = True) 

#california_data_df display with the new columns
##Note: california_data_df["Phone Number"] needs to contain only the digits of the phone number
##Note: california_data_df["Contact Information4"] still needs cleaning
california_data_df.head()
# Out:
#     License Number                    License Type  \
# 0  C11-0000034-LIC  Cannabis - Distributor License
# 1  C11-0000035-LIC  Cannabis - Distributor License
# 2  C11-0000036-LIC  Cannabis - Distributor License
# 3  C11-0000037-LIC  Cannabis - Distributor License
# 4  C10-0000028-LIC     Cannabis - Retailer License
#
#                    Business Owner         Business Structure  \
# 0                Bernard Steimann  Limited Liability Company
# 1                  Alicia Schultz                Corporation
# 2                    Connie Bauer                Corporation
# 3              Marcella Castaneda                Corporation
# 4  Chelsea Sutula: Chelsea Sutula                Corporation
#
#                                   Premise Address  Status  Issue Date  \
# 0  CATHEDRAL CITY, CA 922347624 County: RIVERSIDE  Active  05/02/2019
# 1      Cathedral City, CA 92234 County: RIVERSIDE  Active  05/02/2019
# 2            KING CITY, CA 93930 County: MONTEREY  Active  05/02/2019
# 3       ADELANTO, CA 92301 County: SAN BERNARDINO  Active  05/02/2019
# 4   408 BRYANT CIR OJAI, CA 93023 County: VENTURA  Active  05/01/2019
#
#   Expiration Date                 Activities Adult-Use/Medicinal  \
# 0      05/01/2020  N/A for this license type                BOTH
# 1      05/01/2020  N/A for this license type                BOTH
# 2      05/01/2020  N/A for this license type                BOTH
# 3      05/01/2020  N/A for this license type           Medicinal
# 4      04/30/2020  N/A for this license type                BOTH
#
#                              Company Name                        Email  \
# 0                             PDC, LLC              license@pmcoc.com
# 1        WE CARE CAT CITY INC.    GUIDE       Georgedggroup@gmail.com
# 2  GREENFIELD HERBS    Greenfield Herbs     carol@greenfieldherbs.com
# 3                 BEAVER FREIGHT, INC.         mcastaneda85@gmail.com
# 4         SESPE CREEK COLLECTIVE, INC.                 info@sespe.org
#
#           Phone Number          Contact Information4
# 0   Phone- 7144857379    Website- www.herodistro.com
# 1    Phone- 7606737220                          None
# 2    Phone- 8318095469                          None
# 3    Phone- 9099638849                          None
# 4   Phone- 8557229333         Website- www.sespe.org

# %%
#Clean up california_data_df["Phone Number"] so that it shows only the digits of phone number
#(ie. Remove the string ("Phone-") from the column

# dropping null value columns to avoid errors 
california_data_df.dropna(inplace = True) 
  
# new data frame with split value columns 
new = california_data_df["Phone Number"].str.split("-", n = 1, expand = True) 
  
# making separate "Phone str" column from new data frame to extract the unwanted string
california_data_df["Phone str"]= new[0] 
  
# making separate "Telephone Number" column from new data frame 
california_data_df["Telephone Number"]= new[1] 

# Dropping california_data_df["Phone str"] and california_data_df["Phone Number"] columns
california_data_df.drop(columns =["Phone Number"], inplace = True)
california_data_df.drop(columns =["Phone str"], inplace = True) 

#california_data_df display with the new columns
##Note: california_data_df["Contact Information4"] still needs cleaning
california_data_df.head()
# Out:
#      License Number                    License Type  \
# 0   C11-0000034-LIC  Cannabis - Distributor License
# 4   C10-0000028-LIC     Cannabis - Retailer License
# 7   C10-0000029-LIC     Cannabis - Retailer License
# 8   C10-0000030-LIC     Cannabis - Retailer License
# 13  C11-0000027-LIC  Cannabis - Distributor License
#
#                     Business Owner         Business Structure  \
# 0                 Bernard Steimann  Limited Liability Company
# 4   Chelsea Sutula: Chelsea Sutula                Corporation
# 7                   Julie Montante  Limited Liability Company
# 8                       David Moss  Limited Liability Company
# 13                 Elizabeth Cooke  Limited Liability Company
#
#                                       Premise Address  Status  Issue Date  \
# 0      CATHEDRAL CITY, CA 922347624 County: RIVERSIDE  Active  05/02/2019
# 4       408 BRYANT CIR OJAI, CA 93023 County: VENTURA  Active  05/01/2019
# 7   400 E. Sunny Dunes RD Palm Springs, CA 92264 C...  Active  05/01/2019
# 8   2675 VENTURA RD PORT HUENEME, CA 930412054 Cou...  Active  05/01/2019
# 13              OAKLAND, CA 946214432 County: ALAMEDA  Active  05/01/2019
#
#    Expiration Date                 Activities Adult-Use/Medicinal  \
# 0       05/01/2020  N/A for this license type                BOTH
# 4       04/30/2020  N/A for this license type                BOTH
# 7       04/30/2020  N/A for this license type                BOTH
# 8       04/30/2020  N/A for this license type                BOTH
# 13      04/30/2020  N/A for this license type                BOTH
#
#                                          Company Name  \
# 0                                         PDC, LLC
# 4                     SESPE CREEK COLLECTIVE, INC.
# 7                        PALM SPRINGS ORGANICS LLC
# 8         DBO INVESTMENTS PH, LLC    From The Earth
# 13  THE GROW FOUNDRY CALIFORNIA, LLC    Coda Signa...
#
#                             Email             Contact Information4  \
# 0              license@pmcoc.com       Website- www.herodistro.com
# 4                 info@sespe.org            Website- www.sespe.org
# 7               jmexotic@aol.com          Website- psaorganica.com
# 8                   d@fteusa.com               Website- fteusa.com
# 13   elizabeth@codasignature.com    Website- www.codasignature.com
#
#    Telephone Number
# 0       7144857379
# 4       8557229333
# 7       7602506477
# 8       8054141394
# 13      8444202632

# %%
#Clean up the california_data_df["Contact Information4"] column so that it shows only the actual website address
#(ie. Remove the string ("Website-") from the column

# dropping null value columns to avoid errors 
california_data_df.dropna(inplace = True) 
  
# new data frame with split value columns 
new = california_data_df["Contact Information4"].str.split("-", n = 1, expand = True) 
  
# making separate "Website str" column from new data frame to extract the unwanted string
california_data_df["Website str"]= new[0]     
  
# making separate "Website Address" column from new data frame 
california_data_df["Website Address"]= new[1] 

# Dropping california_data_df["Website str"] and california_data_df["Contact Information4"] columns
california_data_df.drop(columns =["Contact Information4"], inplace = True)
california_data_df.drop(columns =["Website str"], inplace = True) 

#california_data_df display with the new columns
california_data_df.head()

##SECTION 2.1 Completed
##################################################################################################################
# Out:
#      License Number                    License Type  \
# 0   C11-0000034-LIC  Cannabis - Distributor License
# 4   C10-0000028-LIC     Cannabis - Retailer License
# 7   C10-0000029-LIC     Cannabis - Retailer License
# 8   C10-0000030-LIC     Cannabis - Retailer License
# 13  C11-0000027-LIC  Cannabis - Distributor License
#
#                     Business Owner         Business Structure  \
# 0                 Bernard Steimann  Limited Liability Company
# 4   Chelsea Sutula: Chelsea Sutula                Corporation
# 7                   Julie Montante  Limited Liability Company
# 8                       David Moss  Limited Liability Company
# 13                 Elizabeth Cooke  Limited Liability Company
#
#                                       Premise Address  Status  Issue Date  \
# 0      CATHEDRAL CITY, CA 922347624 County: RIVERSIDE  Active  05/02/2019
# 4       408 BRYANT CIR OJAI, CA 93023 County: VENTURA  Active  05/01/2019
# 7   400 E. Sunny Dunes RD Palm Springs, CA 92264 C...  Active  05/01/2019
# 8   2675 VENTURA RD PORT HUENEME, CA 930412054 Cou...  Active  05/01/2019
# 13              OAKLAND, CA 946214432 County: ALAMEDA  Active  05/01/2019
#
#    Expiration Date                 Activities Adult-Use/Medicinal  \
# 0       05/01/2020  N/A for this license type                BOTH
# 4       04/30/2020  N/A for this license type                BOTH
# 7       04/30/2020  N/A for this license type                BOTH
# 8       04/30/2020  N/A for this license type                BOTH
# 13      04/30/2020  N/A for this license type                BOTH
#
#                                          Company Name  \
# 0                                         PDC, LLC
# 4                     SESPE CREEK COLLECTIVE, INC.
# 7                        PALM SPRINGS ORGANICS LLC
# 8         DBO INVESTMENTS PH, LLC    From The Earth
# 13  THE GROW FOUNDRY CALIFORNIA, LLC    Coda Signa...
#
#                             Email Telephone Number         Website Address
# 0              license@pmcoc.com       7144857379       www.herodistro.com
# 4                 info@sespe.org       8557229333            www.sespe.org
# 7               jmexotic@aol.com       7602506477          psaorganica.com
# 8                   d@fteusa.com       8054141394               fteusa.com
# 13   elizabeth@codasignature.com       8444202632    www.codasignature.com

# %% [raw]
# ##################################################################################################################
# ## SECTION 2.2
# #Clean the "Premise Address" column
# ##Objective: Clean the data in california_data_df["Premise Address"]
# ##################################################################################################################

# %%
#Business Contact Information column cleanup:
california_data_df["Premise Address"].head()
#Note that there are multiple delimiters: a colon (":"), a comma (","), and a blank space (" ")
#Note that the zip codes have either 5 or 9 digits
# Out:
# 0        CATHEDRAL CITY, CA 922347624 County: RIVERSIDE
# 4         408 BRYANT CIR OJAI, CA 93023 County: VENTURA
# 7     400 E. Sunny Dunes RD Palm Springs, CA 92264 C...
# 8     2675 VENTURA RD PORT HUENEME, CA 930412054 Cou...
# 13                OAKLAND, CA 946214432 County: ALAMEDA
# Name: Premise Address, dtype: object

# %%
##Extract and separate "County" from the california_data_df["Premise Address"] column

# dropping null value columns to avoid errors 
california_data_df.dropna(inplace = True) 
  
# new data frame with split value columns 
new = california_data_df["Premise Address"].str.split(":", n = 1, expand = True) 
  
# making separate "Business Name" column from new data frame 
california_data_df["Premise Address2"]= new[0] 
  
# making separate "Contact Information" column from new data frame 
california_data_df["County"]= new[1] 

# Dropping california_data_df["Premise Address"] column
california_data_df.drop(columns =["Premise Address"], inplace = True) 

#california_data_df display with the new columns
##Note: california_data_df["County"] still needs cleaning
##Note: california_data_df["Premise Address2"] still needs cleaning
california_data_df.head()
# Out:
#      License Number                    License Type  \
# 0   C11-0000034-LIC  Cannabis - Distributor License
# 4   C10-0000028-LIC     Cannabis - Retailer License
# 7   C10-0000029-LIC     Cannabis - Retailer License
# 8   C10-0000030-LIC     Cannabis - Retailer License
# 13  C11-0000027-LIC  Cannabis - Distributor License
#
#                     Business Owner         Business Structure  Status  \
# 0                 Bernard Steimann  Limited Liability Company  Active
# 4   Chelsea Sutula: Chelsea Sutula                Corporation  Active
# 7                   Julie Montante  Limited Liability Company  Active
# 8                       David Moss  Limited Liability Company  Active
# 13                 Elizabeth Cooke  Limited Liability Company  Active
#
#     Issue Date Expiration Date                 Activities Adult-Use/Medicinal  \
# 0   05/02/2019      05/01/2020  N/A for this license type                BOTH
# 4   05/01/2019      04/30/2020  N/A for this license type                BOTH
# 7   05/01/2019      04/30/2020  N/A for this license type                BOTH
# 8   05/01/2019      04/30/2020  N/A for this license type                BOTH
# 13  05/01/2019      04/30/2020  N/A for this license type                BOTH
#
#                                          Company Name  \
# 0                                         PDC, LLC
# 4                     SESPE CREEK COLLECTIVE, INC.
# 7                        PALM SPRINGS ORGANICS LLC
# 8         DBO INVESTMENTS PH, LLC    From The Earth
# 13  THE GROW FOUNDRY CALIFORNIA, LLC    Coda Signa...
#
#                             Email Telephone Number         Website Address  \
# 0              license@pmcoc.com       7144857379       www.herodistro.com
# 4                 info@sespe.org       8557229333            www.sespe.org
# 7               jmexotic@aol.com       7602506477          psaorganica.com
# 8                   d@fteusa.com       8054141394               fteusa.com
# 13   elizabeth@codasignature.com       8444202632    www.codasignature.com
#
#                                      Premise Address2      County
# 0                 CATHEDRAL CITY, CA 922347624 County   RIVERSIDE
# 4                408 BRYANT CIR OJAI, CA 93023 County     VENTURA
# 7   400 E. Sunny Dunes RD Palm Springs, CA 92264 C...   RIVERSIDE
# 8   2675 VENTURA RD PORT HUENEME, CA 930412054 County     VENTURA
# 13                       OAKLAND, CA 946214432 County     ALAMEDA

# %%
#Clean up california_data_df["County"] -- Problem: all letters in the column are capitalized, and we need to fix this

#Adjust the case structure so that only the first letter in "County" is capitalized while all others are lower case
california_data_df["County"] = california_data_df["County"].str.title()

#california_data_df display with the new columns
##Note: california_data_df["Premise Address3"] still needs cleaning
california_data_df.head()
# Out:
#      License Number                    License Type  \
# 0   C11-0000034-LIC  Cannabis - Distributor License
# 4   C10-0000028-LIC     Cannabis - Retailer License
# 7   C10-0000029-LIC     Cannabis - Retailer License
# 8   C10-0000030-LIC     Cannabis - Retailer License
# 13  C11-0000027-LIC  Cannabis - Distributor License
#
#                     Business Owner         Business Structure  Status  \
# 0                 Bernard Steimann  Limited Liability Company  Active
# 4   Chelsea Sutula: Chelsea Sutula                Corporation  Active
# 7                   Julie Montante  Limited Liability Company  Active
# 8                       David Moss  Limited Liability Company  Active
# 13                 Elizabeth Cooke  Limited Liability Company  Active
#
#     Issue Date Expiration Date                 Activities Adult-Use/Medicinal  \
# 0   05/02/2019      05/01/2020  N/A for this license type                BOTH
# 4   05/01/2019      04/30/2020  N/A for this license type                BOTH
# 7   05/01/2019      04/30/2020  N/A for this license type                BOTH
# 8   05/01/2019      04/30/2020  N/A for this license type                BOTH
# 13  05/01/2019      04/30/2020  N/A for this license type                BOTH
#
#                                          Company Name  \
# 0                                         PDC, LLC
# 4                     SESPE CREEK COLLECTIVE, INC.
# 7                        PALM SPRINGS ORGANICS LLC
# 8         DBO INVESTMENTS PH, LLC    From The Earth
# 13  THE GROW FOUNDRY CALIFORNIA, LLC    Coda Signa...
#
#                             Email Telephone Number         Website Address  \
# 0              license@pmcoc.com       7144857379       www.herodistro.com
# 4                 info@sespe.org       8557229333            www.sespe.org
# 7               jmexotic@aol.com       7602506477          psaorganica.com
# 8                   d@fteusa.com       8054141394               fteusa.com
# 13   elizabeth@codasignature.com       8444202632    www.codasignature.com
#
#                                      Premise Address2      County
# 0                 CATHEDRAL CITY, CA 922347624 County   Riverside
# 4                408 BRYANT CIR OJAI, CA 93023 County     Ventura
# 7   400 E. Sunny Dunes RD Palm Springs, CA 92264 C...   Riverside
# 8   2675 VENTURA RD PORT HUENEME, CA 930412054 County     Ventura
# 13                       OAKLAND, CA 946214432 County     Alameda

# %%
#Clean up california_data_df["Premise Address2"] so that the superfluous string "County" can be excised
#(ie. Remove the string ("County") now that the actual county has been extracted into its own column

#Drop the 'County' string from the "Premise Address2" columnn
california_data_df["Premise Address3"] = california_data_df["Premise Address2"].str.replace('County,?' , '')

# Dropping old "Premise Address2" column
california_data_df.drop(columns =["Premise Address2"], inplace = True)

#california_data_df display with the new columns
##Note: california_data_df["Premise Address3"] still needs cleaning
california_data_df.head()
# Out:
#      License Number                    License Type  \
# 0   C11-0000034-LIC  Cannabis - Distributor License
# 4   C10-0000028-LIC     Cannabis - Retailer License
# 7   C10-0000029-LIC     Cannabis - Retailer License
# 8   C10-0000030-LIC     Cannabis - Retailer License
# 13  C11-0000027-LIC  Cannabis - Distributor License
#
#                     Business Owner         Business Structure  Status  \
# 0                 Bernard Steimann  Limited Liability Company  Active
# 4   Chelsea Sutula: Chelsea Sutula                Corporation  Active
# 7                   Julie Montante  Limited Liability Company  Active
# 8                       David Moss  Limited Liability Company  Active
# 13                 Elizabeth Cooke  Limited Liability Company  Active
#
#     Issue Date Expiration Date                 Activities Adult-Use/Medicinal  \
# 0   05/02/2019      05/01/2020  N/A for this license type                BOTH
# 4   05/01/2019      04/30/2020  N/A for this license type                BOTH
# 7   05/01/2019      04/30/2020  N/A for this license type                BOTH
# 8   05/01/2019      04/30/2020  N/A for this license type                BOTH
# 13  05/01/2019      04/30/2020  N/A for this license type                BOTH
#
#                                          Company Name  \
# 0                                         PDC, LLC
# 4                     SESPE CREEK COLLECTIVE, INC.
# 7                        PALM SPRINGS ORGANICS LLC
# 8         DBO INVESTMENTS PH, LLC    From The Earth
# 13  THE GROW FOUNDRY CALIFORNIA, LLC    Coda Signa...
#
#                             Email Telephone Number         Website Address  \
# 0              license@pmcoc.com       7144857379       www.herodistro.com
# 4                 info@sespe.org       8557229333            www.sespe.org
# 7               jmexotic@aol.com       7602506477          psaorganica.com
# 8                   d@fteusa.com       8054141394               fteusa.com
# 13   elizabeth@codasignature.com       8444202632    www.codasignature.com
#
#         County                               Premise Address3
# 0    Riverside                  CATHEDRAL CITY, CA 922347624
# 4      Ventura                 408 BRYANT CIR OJAI, CA 93023
# 7    Riverside  400 E. Sunny Dunes RD Palm Springs, CA 92264
# 8      Ventura    2675 VENTURA RD PORT HUENEME, CA 930412054
# 13     Alameda                         OAKLAND, CA 946214432

# %%
##Extract and separate "Address" from the "Premise Address3" column.

# dropping null value columns to avoid errors 
california_data_df.dropna(inplace = True) 
  
# new data frame with split value columns 
new = california_data_df["Premise Address3"].str.split(",", n = 1, expand = True) 
  
# making separate "Address" column from new data frame 
california_data_df["Address_misc"]= new[0] 
  
# making separate "State/Zip Code" column from new data frame 
california_data_df["State/Zip Code"]= new[1] 

# Dropping old "Premise Address3" column
california_data_df.drop(columns =["Premise Address3"], inplace = True) 

#california_data_df display with the new columns
## Note: california_data_df["Address misc"] and california_data_df["StateSip Code"] BOTH still need cleaning 
california_data_df.head()
# Out:
#      License Number                    License Type  \
# 0   C11-0000034-LIC  Cannabis - Distributor License
# 4   C10-0000028-LIC     Cannabis - Retailer License
# 7   C10-0000029-LIC     Cannabis - Retailer License
# 8   C10-0000030-LIC     Cannabis - Retailer License
# 13  C11-0000027-LIC  Cannabis - Distributor License
#
#                     Business Owner         Business Structure  Status  \
# 0                 Bernard Steimann  Limited Liability Company  Active
# 4   Chelsea Sutula: Chelsea Sutula                Corporation  Active
# 7                   Julie Montante  Limited Liability Company  Active
# 8                       David Moss  Limited Liability Company  Active
# 13                 Elizabeth Cooke  Limited Liability Company  Active
#
#     Issue Date Expiration Date                 Activities Adult-Use/Medicinal  \
# 0   05/02/2019      05/01/2020  N/A for this license type                BOTH
# 4   05/01/2019      04/30/2020  N/A for this license type                BOTH
# 7   05/01/2019      04/30/2020  N/A for this license type                BOTH
# 8   05/01/2019      04/30/2020  N/A for this license type                BOTH
# 13  05/01/2019      04/30/2020  N/A for this license type                BOTH
#
#                                          Company Name  \
# 0                                         PDC, LLC
# 4                     SESPE CREEK COLLECTIVE, INC.
# 7                        PALM SPRINGS ORGANICS LLC
# 8         DBO INVESTMENTS PH, LLC    From The Earth
# 13  THE GROW FOUNDRY CALIFORNIA, LLC    Coda Signa...
#
#                             Email Telephone Number         Website Address  \
# 0              license@pmcoc.com       7144857379       www.herodistro.com
# 4                 info@sespe.org       8557229333            www.sespe.org
# 7               jmexotic@aol.com       7602506477          psaorganica.com
# 8                   d@fteusa.com       8054141394               fteusa.com
# 13   elizabeth@codasignature.com       8444202632    www.codasignature.com
#
#         County                        Address_misc  State/Zip Code
# 0    Riverside                      CATHEDRAL CITY   CA 922347624
# 4      Ventura                 408 BRYANT CIR OJAI       CA 93023
# 7    Riverside  400 E. Sunny Dunes RD Palm Springs       CA 92264
# 8      Ventura        2675 VENTURA RD PORT HUENEME   CA 930412054
# 13     Alameda                             OAKLAND   CA 946214432

# %%
#Drop the 'CA' string from the State/Zip Code column, since the State information is superfluous
california_data_df["Zip Code"] = california_data_df["State/Zip Code"].str.replace('CA,?' ,'')

# Dropping old "State/Zip Code" column
california_data_df.drop(columns =["State/Zip Code"], inplace = True)

#california_data_df display with the new columns
## Note: california_data_df["Address_misc"] and california_data_df["Zip Code"] BOTH still need cleaning 
california_data_df.head()
# Out:
#      License Number                    License Type  \
# 0   C11-0000034-LIC  Cannabis - Distributor License
# 4   C10-0000028-LIC     Cannabis - Retailer License
# 7   C10-0000029-LIC     Cannabis - Retailer License
# 8   C10-0000030-LIC     Cannabis - Retailer License
# 13  C11-0000027-LIC  Cannabis - Distributor License
#
#                     Business Owner         Business Structure  Status  \
# 0                 Bernard Steimann  Limited Liability Company  Active
# 4   Chelsea Sutula: Chelsea Sutula                Corporation  Active
# 7                   Julie Montante  Limited Liability Company  Active
# 8                       David Moss  Limited Liability Company  Active
# 13                 Elizabeth Cooke  Limited Liability Company  Active
#
#     Issue Date Expiration Date                 Activities Adult-Use/Medicinal  \
# 0   05/02/2019      05/01/2020  N/A for this license type                BOTH
# 4   05/01/2019      04/30/2020  N/A for this license type                BOTH
# 7   05/01/2019      04/30/2020  N/A for this license type                BOTH
# 8   05/01/2019      04/30/2020  N/A for this license type                BOTH
# 13  05/01/2019      04/30/2020  N/A for this license type                BOTH
#
#                                          Company Name  \
# 0                                         PDC, LLC
# 4                     SESPE CREEK COLLECTIVE, INC.
# 7                        PALM SPRINGS ORGANICS LLC
# 8         DBO INVESTMENTS PH, LLC    From The Earth
# 13  THE GROW FOUNDRY CALIFORNIA, LLC    Coda Signa...
#
#                             Email Telephone Number         Website Address  \
# 0              license@pmcoc.com       7144857379       www.herodistro.com
# 4                 info@sespe.org       8557229333            www.sespe.org
# 7               jmexotic@aol.com       7602506477          psaorganica.com
# 8                   d@fteusa.com       8054141394               fteusa.com
# 13   elizabeth@codasignature.com       8444202632    www.codasignature.com
#
#         County                        Address_misc      Zip Code
# 0    Riverside                      CATHEDRAL CITY    922347624
# 4      Ventura                 408 BRYANT CIR OJAI        93023
# 7    Riverside  400 E. Sunny Dunes RD Palm Springs        92264
# 8      Ventura        2675 VENTURA RD PORT HUENEME    930412054
# 13     Alameda                             OAKLAND    946214432

# %%
#Note: Some of the data in the "Zip Code" column has 9 digits, wihle others have 5 digits
california_data_df["Zip Code"].head()
#Need to clean up the "Zip Code" data so that the zip code is the standard 5-digit code
# Out:
# 0       922347624
# 4           93023
# 7           92264
# 8       930412054
# 13      946214432
# Name: Zip Code, dtype: object

# %%
#Clean up "Zip Code" column so that the zip code is the standard 5-digit code, and not the 9-digit code that appers sporadically above
california_data_df['Zip Code'] = california_data_df['Zip Code'].str[:7]
california_data_df.head()

##SECTION 2.2 Completed
##################################################################################################################
# Out:
#      License Number                    License Type  \
# 0   C11-0000034-LIC  Cannabis - Distributor License
# 4   C10-0000028-LIC     Cannabis - Retailer License
# 7   C10-0000029-LIC     Cannabis - Retailer License
# 8   C10-0000030-LIC     Cannabis - Retailer License
# 13  C11-0000027-LIC  Cannabis - Distributor License
#
#                     Business Owner         Business Structure  Status  \
# 0                 Bernard Steimann  Limited Liability Company  Active
# 4   Chelsea Sutula: Chelsea Sutula                Corporation  Active
# 7                   Julie Montante  Limited Liability Company  Active
# 8                       David Moss  Limited Liability Company  Active
# 13                 Elizabeth Cooke  Limited Liability Company  Active
#
#     Issue Date Expiration Date                 Activities Adult-Use/Medicinal  \
# 0   05/02/2019      05/01/2020  N/A for this license type                BOTH
# 4   05/01/2019      04/30/2020  N/A for this license type                BOTH
# 7   05/01/2019      04/30/2020  N/A for this license type                BOTH
# 8   05/01/2019      04/30/2020  N/A for this license type                BOTH
# 13  05/01/2019      04/30/2020  N/A for this license type                BOTH
#
#                                          Company Name  \
# 0                                         PDC, LLC
# 4                     SESPE CREEK COLLECTIVE, INC.
# 7                        PALM SPRINGS ORGANICS LLC
# 8         DBO INVESTMENTS PH, LLC    From The Earth
# 13  THE GROW FOUNDRY CALIFORNIA, LLC    Coda Signa...
#
#                             Email Telephone Number         Website Address  \
# 0              license@pmcoc.com       7144857379       www.herodistro.com
# 4                 info@sespe.org       8557229333            www.sespe.org
# 7               jmexotic@aol.com       7602506477          psaorganica.com
# 8                   d@fteusa.com       8054141394               fteusa.com
# 13   elizabeth@codasignature.com       8444202632    www.codasignature.com
#
#         County                        Address_misc Zip Code
# 0    Riverside                      CATHEDRAL CITY    92234
# 4      Ventura                 408 BRYANT CIR OJAI    93023
# 7    Riverside  400 E. Sunny Dunes RD Palm Springs    92264
# 8      Ventura        2675 VENTURA RD PORT HUENEME    93041
# 13     Alameda                             OAKLAND    94621

# %%
#Choose the most important columns for the next part of the ETL Project
california_data_df = california_data_df[["Company Name","Website Address","County","Zip Code"]]
california_data_df.head()
california_data_df.reset_index(drop=True)
# Out:
#                                           Company Name  \
# 0                                          PDC, LLC
# 1                      SESPE CREEK COLLECTIVE, INC.
# 2                         PALM SPRINGS ORGANICS LLC
# 3          DBO INVESTMENTS PH, LLC    From The Earth
# 4    THE GROW FOUNDRY CALIFORNIA, LLC    Coda Signa...
# 5           REVIVE ORGANICS, LLC    Revive Pure Life
# 6     CI DISTRIBUTION LLC    Claybourne Distribution
# 7                                  BLUM SAN LEANDRO
# 8    CROSSTOWN CALIFORNIA HOLDINGS LLC    N-FUZED; ...
# 9                     SUNSHINE HOLISTIC    Sovereign
# 10       ACCENSUS GROUP LLC    Canna Trading Company
# 11         P&B LABS HUMBOLDT LLC    Papa and Barkley
# 12            GOLD FLORA PARTNERS LLC    King's Crew
# 13                          GREENPOINT HOLDINGS LLC
# 14   CALI KOSHER, INC    Empire Health and Wellness...
# 15           Chersse Benton    Posh Green Collective
# 16   CALIFORNIA STATE DISTRIBUTION, LLC    Californ...
# 17          JAHnetics Delivery    Jahnetics Delivery
# 18                         WILDSEED, LLC    Wildseed
# 19                    Joint Venture Industries, Inc
# 20                       TAHOE WELLNESS COOPERATIVE
# 21                        EMERALD CITY DISTRIBUTION
# 22                        CAE MGMT    CAE MANAGEMENT
# 23     MISSION HERBAL CARE INC    THE COOKIE COMPANY
# 24                       GREEN SPIRIT MENDOCINO LLC
# 25                   US BLOOM COLLECTIVE    US Bloom
# 26   ALTERNATIVES, A HEALTH COLLECTIVE    ALTERNATI...
# 27                                          MOVOCAN
# 28                                          MOVOCAN
# 29                                          MOVOCAN
# ..                                                 ...
# 966                THE SOURCE SANTA ANA    MedMen OC
# 967                        CBD INC    From The Earth
# 968                            PT KOR INC.    korova
# 969          MAG WELLNESS, INC.    Magnolia Wellness
# 970                             FLOR X, INC    Florx
# 971             HIGHER LEVEL OF CARE    Higher Level
# 972                 CANNDESCENT, INC.    Canndescent
# 973                 CANNDESCENT, INC.    Canndescent
# 974     THE RICHMOND PATIENT'S GROUP    Green Remedy
# 975          EVENT HORIZON TECHNOLOGIES    Flow Kana
# 976                     WILLPOWER LLC    New life CA
# 977  THE GREEN HEART COLLECTIVE. ORG    The Green H...
# 978  ALTERNATIVE HEALTH CARE ADVOCATES    Los Angel...
# 979          MIGLIORE, LLC    Abatin Wellness Center
# 980  BSCB ENTERPRISES LLC    Big Sur Cannabotanicals
# 981              ZEN HEALING COLLECTIVE CORPORATION
# 982  HNHPC, A NONPROFIT MUTUAL BENEFIT CORP    Conn...
# 983                          CURBSTONE EXCHANGE LLC
# 984              RIVER CITY PHOENIX    Perfect Union
# 985  SACRAMENTO COMMUNITY CANNABIS COLLECTIVE    Co...
# 986                        GOLDEN HEALTH & WELLNESS
# 987              CURA CA, LLC    Cura Vape Equipment
# 988                ALTERNATIVE MEDICAL CENTER    AMC
# 989        P&B LABS HUMBOLDT LLC    Papa and Barkley
# 990                                   BUD AND BLOOM
# 991                        PSGC, INC.    Atomic Budz
# 992          EVENT HORIZON TECHNOLOGIES    Flow Kana
# 993  NATURAL CANNABIS COMPANY, LLC    Natural Canna...
# 994                      BCSF, INC.    Barbary Coast
# 995                                      URB SF INC
#
#                           Website Address            County Zip Code
# 0                      www.herodistro.com         Riverside    92234
# 1                           www.sespe.org           Ventura    93023
# 2                         psaorganica.com         Riverside    92264
# 3                              fteusa.com           Ventura    93041
# 4                   www.codasignature.com           Alameda    94621
# 5                  www.revivepurelife.com            Nevada    95959
# 6          www.claybournedistribution.com         Riverside    92571
# 7                        www.letsblum.com           Alameda    94577
# 8                 https://www.nfuzed.com/   San Luis Obispo    93433
# 9                    www.sovereign707.org         Mendocino    95437
# 10                       cannatrading.com          Siskiyou    96094
# 11                 www.papaandbarkley.com          Humboldt    95501
# 12                      www.kingscrew.com       Los Angeles    90814
# 13          www.greenpointholdingsllc.com       Los Angeles    90805
# 14                           1631 FIG AVE        Stanislaus    95361
# 15            www.poshgreencollective.com     San Francisco    94102
# 16    www.californiastatedistribution.com            Fresno    93210
# 17                      www.jahnetics.com     San Francisco    94111
# 18                    www.wildseedoil.com          Humboldt    95521
# 19                      www.jvmigroup.com    San Bernardino    92301
# 20              www.tahoewellnesscoop.org         El Dorado    96150
# 21                     300 EAST HILL ROAD         Mendocino    95490
# 22                     7801 3RD GATE ROAD         Mendocino    95490
# 23                    www.cookieco415.com     San Francisco    94110
# 24         www.thegreenroomcollective.com         Mendocino    95468
# 25                        1201 Springs Rd            Solano    94591
# 26         www.alternativescollective.com            Sonoma    95407
# 27                        www.movocan.com          Imperial    92231
# 28                        www.movocan.com          Imperial    92231
# 29                        www.movocan.com          Imperial    92231
# ..                                    ...               ...      ...
# 966                        www.medmen.com            Orange    92705
# 967                         www.fteoc.com            Orange    92707
# 968                 www.korovaedibles.com           Alameda    94621
# 969              www.magnoliawellness.org           Alameda    94607
# 970                         grupoflor.com          Monterey    93901
# 971         http://www.higherlevelmmj.com          Monterey    95012
# 972                  www.canndescent.com/         Riverside    92240
# 973                   www.canndescent.com         Riverside    92240
# 974         www.greenremedycollective.com      Contra Costa    94806
# 975                      www.flowkana.com         Mendocino    95454
# 976                     www.newlifeca.com           Alameda    94621
# 977       www.thegreenheartcollective.org          Siskiyou    96067
# 978     http://www.lamedicalmarijuana.com       Los Angeles    90046
# 979      http://www.abatinsacramento.com/        Sacramento    95817
# 980             bigsurcannabotanicals.com          Monterey    93923
# 981                       www.zenweho.com       Los Angeles    90069
# 982               connectedcannabisco.com            Orange    92705
# 983                 curbstoneexchange.org        Santa Cruz    95018
# 984                 www.rcpsacramento.org        Sacramento    95815
# 985               connectedcannabisco.com        Sacramento    95820
# 986                  goldensacramento.com        Sacramento    95815
# 987                       www.curacan.com        Sacramento    95828
# 988                     amcsacramento.com        Sacramento    95815
# 989                www.papaandbarkley.com          Humboldt    95501
# 990                 www.budandbloomoc.com            Orange    92705
# 991              68415 Perez Rd., suite a         Riverside    92234
# 992                      www.flowkana.com           Alameda    94606
# 993               www.naturalcannabis.com            Sonoma    95407
# 994                www.barbarycoastsf.org     San Francisco    94103
# 995                       urbdelivery.com           Alameda    94621
#
# [996 rows x 4 columns]

# %%
#lets load the Latitude and Longitude coordinates from the csv we created from the API
lat_lng= pd.read_csv('lat_lng.csv')
lat_lng.columns=['A', 'Latitude', 'Longitude']
lat_lng.reset_index(drop=True)
california_data_df = california_data_df.reset_index(drop=True)
lat_lng
# Out:
#        A   Latitude   Longitude
# 0      0  33.780539 -116.466804
# 1      1  34.443072 -119.237926
# 2      2  33.812404 -116.543471
# 3      3  34.178267 -119.196389
# 4      4  37.804364 -122.271114
# 5      5  39.261561 -121.016059
# 6      6  33.782519 -117.228648
# 7      7  37.703576 -122.168828
# 8      8  35.121642 -120.621282
# 9      9  39.445723 -123.805294
# 10    10  41.424356 -122.384066
# 11    11  40.802071 -124.163673
# 12    12  33.774768 -118.122395
# 13    13  33.770050 -118.193740
# 14    14  37.753119 -120.833922
# 15    15  37.774929 -122.419415
# 16    16  36.139678 -120.360150
# 17    17  37.774929 -122.419415
# 18    18  40.866517 -124.082840
# 19    19  34.582770 -117.409215
# 20    20  38.939926 -119.977187
# 21    21  39.409608 -123.355566
# 22    22  39.409608 -123.355566
# 23    23  37.747010 -122.418709
# 24    24  38.907857 -123.692638
# 25    25  38.105783 -122.227924
# 26    26  38.428267 -122.738230
# 27    27  32.678948 -115.498883
# 28    28  32.689153 -115.388937
# 29    29  32.678948 -115.498883
# ..   ...        ...         ...
# 966  966  33.717511 -117.846666
# 967  967  33.706686 -117.863902
# 968  968  37.804364 -122.271114
# 969  969  37.804364 -122.271114
# 970  970  36.677737 -121.655501
# 971  971  36.766364 -121.758481
# 972  972  33.961124 -116.501678
# 973  973  33.961124 -116.501678
# 974  974  37.978159 -122.331822
# 975  975  39.688212 -123.482794
# 976  976  37.804364 -122.271114
# 977  977  41.307781 -122.311289
# 978  978  34.090840 -118.346705
# 979  979  38.561372 -121.473925
# 980  980  36.540876 -121.906659
# 981  981  34.089615 -118.375614
# 982  982  33.715009 -117.844376
# 983  983  37.055885 -122.075395
# 984  984  38.610198 -121.432852
# 985  985  38.525222 -121.476379
# 986  986  38.600880 -121.441243
# 987  987  38.581572 -121.494400
# 988  988  38.604079 -121.438621
# 989  989  40.802071 -124.163673
# 990  990  33.719851 -117.852724
# 991  991  33.784491 -116.468372
# 992  992  37.804364 -122.271114
# 993  993  38.440429 -122.714055
# 994  994  37.781935 -122.407793
# 995  995  37.804364 -122.271114
#
# [996 rows x 3 columns]

# %%
california_data_df = pd.merge(california_data_df, lat_lng, left_index=True, right_index=True)
#california_data_df.drop(['A'], axis=1, inplace = True)
california_data_df
# Out:
#                                           Company Name  \
# 0                                          PDC, LLC
# 1                      SESPE CREEK COLLECTIVE, INC.
# 2                         PALM SPRINGS ORGANICS LLC
# 3          DBO INVESTMENTS PH, LLC    From The Earth
# 4    THE GROW FOUNDRY CALIFORNIA, LLC    Coda Signa...
# 5           REVIVE ORGANICS, LLC    Revive Pure Life
# 6     CI DISTRIBUTION LLC    Claybourne Distribution
# 7                                  BLUM SAN LEANDRO
# 8    CROSSTOWN CALIFORNIA HOLDINGS LLC    N-FUZED; ...
# 9                     SUNSHINE HOLISTIC    Sovereign
# 10       ACCENSUS GROUP LLC    Canna Trading Company
# 11         P&B LABS HUMBOLDT LLC    Papa and Barkley
# 12            GOLD FLORA PARTNERS LLC    King's Crew
# 13                          GREENPOINT HOLDINGS LLC
# 14   CALI KOSHER, INC    Empire Health and Wellness...
# 15           Chersse Benton    Posh Green Collective
# 16   CALIFORNIA STATE DISTRIBUTION, LLC    Californ...
# 17          JAHnetics Delivery    Jahnetics Delivery
# 18                         WILDSEED, LLC    Wildseed
# 19                    Joint Venture Industries, Inc
# 20                       TAHOE WELLNESS COOPERATIVE
# 21                        EMERALD CITY DISTRIBUTION
# 22                        CAE MGMT    CAE MANAGEMENT
# 23     MISSION HERBAL CARE INC    THE COOKIE COMPANY
# 24                       GREEN SPIRIT MENDOCINO LLC
# 25                   US BLOOM COLLECTIVE    US Bloom
# 26   ALTERNATIVES, A HEALTH COLLECTIVE    ALTERNATI...
# 27                                          MOVOCAN
# 28                                          MOVOCAN
# 29                                          MOVOCAN
# ..                                                 ...
# 966                THE SOURCE SANTA ANA    MedMen OC
# 967                        CBD INC    From The Earth
# 968                            PT KOR INC.    korova
# 969          MAG WELLNESS, INC.    Magnolia Wellness
# 970                             FLOR X, INC    Florx
# 971             HIGHER LEVEL OF CARE    Higher Level
# 972                 CANNDESCENT, INC.    Canndescent
# 973                 CANNDESCENT, INC.    Canndescent
# 974     THE RICHMOND PATIENT'S GROUP    Green Remedy
# 975          EVENT HORIZON TECHNOLOGIES    Flow Kana
# 976                     WILLPOWER LLC    New life CA
# 977  THE GREEN HEART COLLECTIVE. ORG    The Green H...
# 978  ALTERNATIVE HEALTH CARE ADVOCATES    Los Angel...
# 979          MIGLIORE, LLC    Abatin Wellness Center
# 980  BSCB ENTERPRISES LLC    Big Sur Cannabotanicals
# 981              ZEN HEALING COLLECTIVE CORPORATION
# 982  HNHPC, A NONPROFIT MUTUAL BENEFIT CORP    Conn...
# 983                          CURBSTONE EXCHANGE LLC
# 984              RIVER CITY PHOENIX    Perfect Union
# 985  SACRAMENTO COMMUNITY CANNABIS COLLECTIVE    Co...
# 986                        GOLDEN HEALTH & WELLNESS
# 987              CURA CA, LLC    Cura Vape Equipment
# 988                ALTERNATIVE MEDICAL CENTER    AMC
# 989        P&B LABS HUMBOLDT LLC    Papa and Barkley
# 990                                   BUD AND BLOOM
# 991                        PSGC, INC.    Atomic Budz
# 992          EVENT HORIZON TECHNOLOGIES    Flow Kana
# 993  NATURAL CANNABIS COMPANY, LLC    Natural Canna...
# 994                      BCSF, INC.    Barbary Coast
# 995                                      URB SF INC
#
#                           Website Address            County Zip Code    A  \
# 0                      www.herodistro.com         Riverside    92234    0
# 1                           www.sespe.org           Ventura    93023    1
# 2                         psaorganica.com         Riverside    92264    2
# 3                              fteusa.com           Ventura    93041    3
# 4                   www.codasignature.com           Alameda    94621    4
# 5                  www.revivepurelife.com            Nevada    95959    5
# 6          www.claybournedistribution.com         Riverside    92571    6
# 7                        www.letsblum.com           Alameda    94577    7
# 8                 https://www.nfuzed.com/   San Luis Obispo    93433    8
# 9                    www.sovereign707.org         Mendocino    95437    9
# 10                       cannatrading.com          Siskiyou    96094   10
# 11                 www.papaandbarkley.com          Humboldt    95501   11
# 12                      www.kingscrew.com       Los Angeles    90814   12
# 13          www.greenpointholdingsllc.com       Los Angeles    90805   13
# 14                           1631 FIG AVE        Stanislaus    95361   14
# 15            www.poshgreencollective.com     San Francisco    94102   15
# 16    www.californiastatedistribution.com            Fresno    93210   16
# 17                      www.jahnetics.com     San Francisco    94111   17
# 18                    www.wildseedoil.com          Humboldt    95521   18
# 19                      www.jvmigroup.com    San Bernardino    92301   19
# 20              www.tahoewellnesscoop.org         El Dorado    96150   20
# 21                     300 EAST HILL ROAD         Mendocino    95490   21
# 22                     7801 3RD GATE ROAD         Mendocino    95490   22
# 23                    www.cookieco415.com     San Francisco    94110   23
# 24         www.thegreenroomcollective.com         Mendocino    95468   24
# 25                        1201 Springs Rd            Solano    94591   25
# 26         www.alternativescollective.com            Sonoma    95407   26
# 27                        www.movocan.com          Imperial    92231   27
# 28                        www.movocan.com          Imperial    92231   28
# 29                        www.movocan.com          Imperial    92231   29
# ..                                    ...               ...      ...  ...
# 966                        www.medmen.com            Orange    92705  966
# 967                         www.fteoc.com            Orange    92707  967
# 968                 www.korovaedibles.com           Alameda    94621  968
# 969              www.magnoliawellness.org           Alameda    94607  969
# 970                         grupoflor.com          Monterey    93901  970
# 971         http://www.higherlevelmmj.com          Monterey    95012  971
# 972                  www.canndescent.com/         Riverside    92240  972
# 973                   www.canndescent.com         Riverside    92240  973
# 974         www.greenremedycollective.com      Contra Costa    94806  974
# 975                      www.flowkana.com         Mendocino    95454  975
# 976                     www.newlifeca.com           Alameda    94621  976
# 977       www.thegreenheartcollective.org          Siskiyou    96067  977
# 978     http://www.lamedicalmarijuana.com       Los Angeles    90046  978
# 979      http://www.abatinsacramento.com/        Sacramento    95817  979
# 980             bigsurcannabotanicals.com          Monterey    93923  980
# 981                       www.zenweho.com       Los Angeles    90069  981
# 982               connectedcannabisco.com            Orange    92705  982
# 983                 curbstoneexchange.org        Santa Cruz    95018  983
# 984                 www.rcpsacramento.org        Sacramento    95815  984
# 985               connectedcannabisco.com        Sacramento    95820  985
# 986                  goldensacramento.com        Sacramento    95815  986
# 987                       www.curacan.com        Sacramento    95828  987
# 988                     amcsacramento.com        Sacramento    95815  988
# 989                www.papaandbarkley.com          Humboldt    95501  989
# 990                 www.budandbloomoc.com            Orange    92705  990
# 991              68415 Perez Rd., suite a         Riverside    92234  991
# 992                      www.flowkana.com           Alameda    94606  992
# 993               www.naturalcannabis.com            Sonoma    95407  993
# 994                www.barbarycoastsf.org     San Francisco    94103  994
# 995                       urbdelivery.com           Alameda    94621  995
#
#       Latitude   Longitude
# 0    33.780539 -116.466804
# 1    34.443072 -119.237926
# 2    33.812404 -116.543471
# 3    34.178267 -119.196389
# 4    37.804364 -122.271114
# 5    39.261561 -121.016059
# 6    33.782519 -117.228648
# 7    37.703576 -122.168828
# 8    35.121642 -120.621282
# 9    39.445723 -123.805294
# 10   41.424356 -122.384066
# 11   40.802071 -124.163673
# 12   33.774768 -118.122395
# 13   33.770050 -118.193740
# 14   37.753119 -120.833922
# 15   37.774929 -122.419415
# 16   36.139678 -120.360150
# 17   37.774929 -122.419415
# 18   40.866517 -124.082840
# 19   34.582770 -117.409215
# 20   38.939926 -119.977187
# 21   39.409608 -123.355566
# 22   39.409608 -123.355566
# 23   37.747010 -122.418709
# 24   38.907857 -123.692638
# 25   38.105783 -122.227924
# 26   38.428267 -122.738230
# 27   32.678948 -115.498883
# 28   32.689153 -115.388937
# 29   32.678948 -115.498883
# ..         ...         ...
# 966  33.717511 -117.846666
# 967  33.706686 -117.863902
# 968  37.804364 -122.271114
# 969  37.804364 -122.271114
# 970  36.677737 -121.655501
# 971  36.766364 -121.758481
# 972  33.961124 -116.501678
# 973  33.961124 -116.501678
# 974  37.978159 -122.331822
# 975  39.688212 -123.482794
# 976  37.804364 -122.271114
# 977  41.307781 -122.311289
# 978  34.090840 -118.346705
# 979  38.561372 -121.473925
# 980  36.540876 -121.906659
# 981  34.089615 -118.375614
# 982  33.715009 -117.844376
# 983  37.055885 -122.075395
# 984  38.610198 -121.432852
# 985  38.525222 -121.476379
# 986  38.600880 -121.441243
# 987  38.581572 -121.494400
# 988  38.604079 -121.438621
# 989  40.802071 -124.163673
# 990  33.719851 -117.852724
# 991  33.784491 -116.468372
# 992  37.804364 -122.271114
# 993  38.440429 -122.714055
# 994  37.781935 -122.407793
# 995  37.804364 -122.271114
#
# [996 rows x 7 columns]

# %% [raw]
# ##################################################################################################################
# ### SECTION 3
# # READ in the california.census.csv file
# ##################################################################################################################

# %%
## Source = https://www.irs.gov/statistics/soi-tax-stats-individual-income-tax-statistics-2016-zip-code-data-soi

# %%
#California_Census_Data
census_data = "../ETL_project/california_2016_census_data.csv"
census_data_df = pd.read_csv(census_data)
census_data_df.head(12)
# Out:
#                                            CALIFORNIA  \
# 0   Individual Income Tax Returns: \nSelected Inco...
# 1         [Money amounts are in thousands of dollars]
# 2                                       ZIP\ncode [1]
# 3                                                 NaN
# 4                                                 NaN
# 5                                               00000
# 6                                               00000
# 7                                               00000
# 8                                               00000
# 9                                               00000
# 10                                              00000
# 11                                              00000
#
#                        Unnamed: 1         Unnamed: 2  \
# 0                             NaN                NaN
# 1                             NaN                NaN
# 2   Size of adjusted gross income  Number of returns
# 3                             NaN                NaN
# 4                             NaN                (1)
# 5                           Total         17,532,400
# 6                $1 under $25,000            5975570
# 7           $25,000 under $50,000            4168180
# 8           $50,000 under $75,000            2328820
# 9          $75,000 under $100,000            1496930
# 10        $100,000 under $200,000            2422990
# 11               $200,000 or more            1139910
#
#                   Unnamed: 3               Unnamed: 4  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2   Number of single returns  Number of joint returns
# 3                        NaN                      NaN
# 4                        (2)                      (3)
# 5                  8,548,270                6,211,790
# 6                    4192510                   774400
# 7                    2113080                  1075050
# 8                    1019940                   919620
# 9                     521570                   794530
# 10                    548060                  1710080
# 11                    153110                   938110
#
#                              Unnamed: 5  \
# 0                                   NaN
# 1                                   NaN
# 2   Number of head of household returns
# 3                                   NaN
# 4                                   (4)
# 5                             2,523,550
# 6                                940840
# 7                                912660
# 8                                344820
# 9                                154380
# 10                               141410
# 11                                29440
#
#                                Unnamed: 6            Unnamed: 7  \
# 0                                     NaN                   NaN
# 1                                     NaN                   NaN
# 2   Number with paid preparer's signature  Number of exemptions
# 3                                     NaN                   NaN
# 4                                     (5)                   (6)
# 5                              10,861,110            35,441,880
# 6                                 3507450               8877550
# 7                                 2571270               8672900
# 8                                 1454740               5086710
# 9                                  952050               3447440
# 10                                1559590               6172950
# 11                                 816010               3184330
#
#               Unnamed: 8                                Unnamed: 9  ...  \
# 0                    NaN                                       NaN  ...
# 1                    NaN                                       NaN  ...
# 2   Number of dependents  Number of volunteer prepared returns [2]  ...
# 3                    NaN                                     Total  ...
# 4                    (7)                                       (8)  ...
# 5             12,566,880                                   292,860  ...
# 6                2969880                                    182750  ...
# 7                3453670                                     85770  ...
# 8                1842140                                     20100  ...
# 9                1155340                                      3590  ...
# 10               2041330                                       650  ...
# 11               1104520                                        **  ...
#
#                 Unnamed: 135 Unnamed: 136                   Unnamed: 137  \
# 0                        NaN          NaN                            NaN
# 1                        NaN          NaN                            NaN
# 2   Total tax liability [10]          NaN  Total additional Medicare tax
# 3          Number of returns       Amount              Number of returns
# 4                      (134)        (135)                          (136)
# 5                 13,713,370  224,205,553                        649,400
# 6                    3119640      3147718                             20
# 7                    3373610      9189547                             20
# 8                    2203430     12647108                             60
# 9                    1470470     13647614                            130
# 10                   2407440     44178605                          29100
# 11                   1138780    141394961                         620070
#
#    Unnamed: 138               Unnamed: 139 Unnamed: 140  \
# 0           NaN                        NaN          NaN
# 1           NaN                        NaN          NaN
# 2           NaN  Net investment income tax          NaN
# 3        Amount          Number of returns       Amount
# 4         (137)                      (138)        (139)
# 5     1,412,144                    661,770    3,184,569
# 6             9                         70          110
# 7             5                         60           23
# 8            14                         60           27
# 9            32                         40           14
# 10         8137                       4270         2728
# 11      1403947                     657270      3181667
#
#                       Unnamed: 141 Unnamed: 142                Unnamed: 143  \
# 0                              NaN          NaN                         NaN
# 1                              NaN          NaN                         NaN
# 2   Tax due at time of filing [11]          NaN  Overpayments refunded [12]
# 3                Number of returns       Amount           Number of returns
# 4                            (140)        (141)                       (142)
# 5                        4,066,410   24,310,929                  12,583,510
# 6                           843690       783942                     4707030
# 7                           782510      1423468                     3309570
# 8                           614100      1616862                     1657290
# 9                           429980      1449379                     1016910
# 10                          822990      4367522                     1487500
# 11                          573140     14669756                      405210
#
#    Unnamed: 144
# 0           NaN
# 1           NaN
# 2           NaN
# 3        Amount
# 4         (143)
# 5    41,461,583
# 6       9411130
# 7       8311140
# 8       4443591
# 9       3367963
# 10      6853759
# 11      9074000
#
# [12 rows x 145 columns]

# %%
#Find the pertinent data and their columns and rename the columns
census_data_df.rename(columns={"CALIFORNIA":"Zip Code"}, inplace=True)
census_data_df.rename(columns={"Unnamed: 1":"Income Bracket"}, inplace=True)
census_data_df.rename(columns={"Unnamed: 65":"Number of Tax Returns"}, inplace=True)
census_data_df.rename(columns={"Unnamed: 66":"Total Income"}, inplace=True)

list(census_data_df)
# Out:
# ['Zip Code',
#  'Income Bracket',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'Unnamed: 26',
#  'Unnamed: 27',
#  'Unnamed: 28',
#  'Unnamed: 29',
#  'Unnamed: 30',
#  'Unnamed: 31',
#  'Unnamed: 32',
#  'Unnamed: 33',
#  'Unnamed: 34',
#  'Unnamed: 35',
#  'Unnamed: 36',
#  'Unnamed: 37',
#  'Unnamed: 38',
#  'Unnamed: 39',
#  'Unnamed: 40',
#  'Unnamed: 41',
#  'Unnamed: 42',
#  'Unnamed: 43',
#  'Unnamed: 44',
#  'Unnamed: 45',
#  'Unnamed: 46',
#  'Unnamed: 47',
#  'Unnamed: 48',
#  'Unnamed: 49',
#  'Unnamed: 50',
#  'Unnamed: 51',
#  'Unnamed: 52',
#  'Unnamed: 53',
#  'Unnamed: 54',
#  'Unnamed: 55',
#  'Unnamed: 56',
#  'Unnamed: 57',
#  'Unnamed: 58',
#  'Unnamed: 59',
#  'Unnamed: 60',
#  'Unnamed: 61',
#  'Unnamed: 62',
#  'Unnamed: 63',
#  'Unnamed: 64',
#  'Number of Tax Returns',
#  'Total Income',
#  'Unnamed: 67',
#  'Unnamed: 68',
#  'Unnamed: 69',
#  'Unnamed: 70',
#  'Unnamed: 71',
#  'Unnamed: 72',
#  'Unnamed: 73',
#  'Unnamed: 74',
#  'Unnamed: 75',
#  'Unnamed: 76',
#  'Unnamed: 77',
#  'Unnamed: 78',
#  'Unnamed: 79',
#  'Unnamed: 80',
#  'Unnamed: 81',
#  'Unnamed: 82',
#  'Unnamed: 83',
#  'Unnamed: 84',
#  'Unnamed: 85',
#  'Unnamed: 86',
#  'Unnamed: 87',
#  'Unnamed: 88',
#  'Unnamed: 89',
#  'Unnamed: 90',
#  'Unnamed: 91',
#  'Unnamed: 92',
#  'Unnamed: 93',
#  'Unnamed: 94',
#  'Unnamed: 95',
#  'Unnamed: 96',
#  'Unnamed: 97',
#  'Unnamed: 98',
#  'Unnamed: 99',
#  'Unnamed: 100',
#  'Unnamed: 101',
#  'Unnamed: 102',
#  'Unnamed: 103',
#  'Unnamed: 104',
#  'Unnamed: 105',
#  'Unnamed: 106',
#  'Unnamed: 107',
#  'Unnamed: 108',
#  'Unnamed: 109',
#  'Unnamed: 110',
#  'Unnamed: 111',
#  'Unnamed: 112',
#  'Unnamed: 113',
#  'Unnamed: 114',
#  'Unnamed: 115',
#  'Unnamed: 116',
#  'Unnamed: 117',
#  'Unnamed: 118',
#  'Unnamed: 119',
#  'Unnamed: 120',
#  'Unnamed: 121',
#  'Unnamed: 122',
#  'Unnamed: 123',
#  'Unnamed: 124',
#  'Unnamed: 125',
#  'Unnamed: 126',
#  'Unnamed: 127',
#  'Unnamed: 128',
#  'Unnamed: 129',
#  'Unnamed: 130',
#  'Unnamed: 131',
#  'Unnamed: 132',
#  'Unnamed: 133',
#  'Unnamed: 134',
#  'Unnamed: 135',
#  'Unnamed: 136',
#  'Unnamed: 137',
#  'Unnamed: 138',
#  'Unnamed: 139',
#  'Unnamed: 140',
#  'Unnamed: 141',
#  'Unnamed: 142',
#  'Unnamed: 143',
#  'Unnamed: 144']

# %%
#Choose the most pertinent columns for the census part of the ETL Project
census_data_df = census_data_df[["Zip Code","Income Bracket","Number of Tax Returns","Total Income"]]
census_data_df.head(19)
# Out:
#                                              Zip Code  \
# 0   Individual Income Tax Returns: \nSelected Inco...
# 1         [Money amounts are in thousands of dollars]
# 2                                       ZIP\ncode [1]
# 3                                                 NaN
# 4                                                 NaN
# 5                                               00000
# 6                                               00000
# 7                                               00000
# 8                                               00000
# 9                                               00000
# 10                                              00000
# 11                                              00000
# 12                                                NaN
# 13                                              90001
# 14                                              90001
# 15                                              90001
# 16                                              90001
# 17                                              90001
# 18                                              90001
#
#                    Income Bracket         Number of Tax Returns Total Income
# 0                             NaN                           NaN          NaN
# 1                             NaN                           NaN          NaN
# 2   Size of adjusted gross income  State and local income taxes          NaN
# 3                             NaN             Number of returns       Amount
# 4                             NaN                          (64)         (65)
# 5                           Total                     5,112,640   80,160,634
# 6                $1 under $25,000                        116550       229306
# 7           $25,000 under $50,000                        457690       815490
# 8           $50,000 under $75,000                        721460      2138961
# 9          $75,000 under $100,000                        807510      3699871
# 10        $100,000 under $200,000                       1915710     16208830
# 11               $200,000 or more                       1093720     57068176
# 12                            NaN                           NaN          NaN
# 13                            NaN                         2,110        5,473
# 14               $1 under $25,000                           150          130
# 15          $25,000 under $50,000                           840         1061
# 16          $50,000 under $75,000                           640         1548
# 17         $75,000 under $100,000                           290         1165
# 18        $100,000 under $200,000                           190         1569

# %% [raw]
# ####################################################################################################################
# ####This CSV file opened with a warning message that some columns had mixed types
# ####We tried anyways to work it through pandas but hit a roadblock
# ##At this point, it looks like we need to return to the Excel file and restructure that file into something more pandas-friendly situation
# ####################################################################################################################

# %%
#Read in new California_Census_Data
census_data2 = "../ETL_project/census_clean.csv"
census_data2_df = pd.read_csv(census_data2)
#Rename the column names
census_data2_df.columns = ["Zip Code","Total Income","Number of Tax Returns"]
census_data2_df.head()
# Out:
#    Zip Code  Total Income  Number of Tax Returns
# 0     90001     619635000                  21670
# 1     90001     171277000                  11890
# 2     90001     245583000                   7020
# 3     90001     116362000                   1940
# 4     90001      47795000                    560

# %%
#Aggregate the group data per Zip Code via groupby function
aggregate_census_data_df = census_data2_df.groupby('Zip Code').sum()
aggregate_census_data_df.head()
# Out:
#           Total Income  Number of Tax Returns
# Zip Code
# 90001       1239270000                  43340
# 90002       1126344000                  39780
# 90003       1461620000                  54580
# 90004       3991172000                  55620
# 90005       1615486000                  31700

# %%
#Create a new "Per Capita Income" column
aggregate_census_data_df["Per Capita Income"] = aggregate_census_data_df["Total Income"]/aggregate_census_data_df["Number of Tax Returns"]
aggregate_census_data_df["Per Capita Income"] = aggregate_census_data_df["Per Capita Income"].round()
aggregate_census_data_df.head()
# Out:
#           Total Income  Number of Tax Returns  Per Capita Income
# Zip Code
# 90001       1239270000                  43340            28594.0
# 90002       1126344000                  39780            28314.0
# 90003       1461620000                  54580            26779.0
# 90004       3991172000                  55620            71758.0
# 90005       1615486000                  31700            50962.0

# %%
#Reformat the "Per Capita Income" column so that it includes comma delimiters per thousand
#This is aesthetically more pleasing on the final product
aggregate_census_data_df["Per Capita Income"] = aggregate_census_data_df["Per Capita Income"].apply("{:,}".format)
aggregate_census_data_df.head()
# Out:
#           Total Income  Number of Tax Returns Per Capita Income
# Zip Code
# 90001       1239270000                  43340          28,594.0
# 90002       1126344000                  39780          28,314.0
# 90003       1461620000                  54580          26,779.0
# 90004       3991172000                  55620          71,758.0
# 90005       1615486000                  31700          50,962.0

# %%
##Clean the "Per Capita Income" column so that the ".0" endof the string is eliminated
# dropping null value columns to avoid errors 
aggregate_census_data_df.dropna(inplace = True) 
  
# new data frame with split value columns 
new = aggregate_census_data_df["Per Capita Income"].str.split(".", n = 1, expand = True) 
  
# making separate "Business Name" column from new data frame 
aggregate_census_data_df["Per Capita Income by Zip Code"]= new[0] 
  
# making separate "misc" column from new data frame 
aggregate_census_data_df["misc"]=new[1]

# Dropping aggregate_census_data["misc"] column
# Dropping aggregate_census_data["Per Capita Income"] column
aggregate_census_data_df.drop(columns =["misc"], inplace = True) 
aggregate_census_data_df.drop(columns =["Per Capita Income"], inplace = True) 

#display with the new columns
aggregate_census_data_df.head()
# Out:
#           Total Income  Number of Tax Returns Per Capita Income by Zip Code
# Zip Code
# 90001       1239270000                  43340                        28,594
# 90002       1126344000                  39780                        28,314
# 90003       1461620000                  54580                        26,779
# 90004       3991172000                  55620                        71,758
# 90005       1615486000                  31700                        50,962

# %% [raw]
# ##################################################################################################################
# ##SECTION 3 Completed
# ##Now we have 2 clean dataframes from 2 distinct sources:
# ##california_data_df contains data pertaining to California Cannabis Licenses
# ##aggregate_census_data_df contains data pertaining to the California Census
# ##These 2 dataframes share "Zip Code" as a commonality that will be joined in the folowing sections of this project
# ##################################################################################################################

# %% [raw]
# ##################################################################################################################
# ### SECTION 4
# # Create SQL Database
# ##################################################################################################################

# %% [raw]
# ##################################################################################################################
# ## SECTION 4.1
# #Switch over to MySQL Workbench
# ##Objective: Create 2 databases in MySQL named california_data and aggegrate_census_data
# ##################################################################################################################
